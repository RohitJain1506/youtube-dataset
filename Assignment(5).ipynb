# %%
#Load Libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print("Done")
# Out:
# Done

# %%
#Load Data
input_file_path = r"C:\Users\Neeru1\Desktop\youtube_rj.csv"
print("Done")
# Out:
# Done

# %%
# Read Data into a DataFrame
df = pd.read_csv(input_file_path)

# %%
#Check the data
df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country  \
# ...

# %%
#Check the data
df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country  \
# ...

# %%
# Change'channeltype' dtatatype from object to string datatype 
df['channeltype'] = df['channeltype'].astype('|S')

# %%
# Check datatypes of all the columns present in The Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   web-scraper-order      1000 non-null   object
#  1   web-scraper-start-url  1000 non-null   object
#  2   userID                 1000 non-null   object
#  3   userID-href            1000 non-null   object
#  4   name                   1000 non-null   object
#  5   uploads                1000 non-null   int64
#  6   subscribers            1000 non-null   int64
#  7   videoviews             1000 non-null   int64
#  8   country                933 non-null    object
#  9   channeltype            1000 non-null   |S16
#  10  usercreated            1000 non-null   object
#  11  grade                  1000 non-null   object
#  12  YouTube_Link           17 non-null     object
#  13  YouTube_Link-href      983 non-null    object
# ...

# %%
# Create new dataframe with top 1000 records
df1=df.head(1000)

# %%
#Create and define new fuction named 'Function_histogram' to create a histogram on
def Function_histogram():
    fig=plt.figure(figsize=(20,20))
    #Use matplotlib to draw a histogram of a Channeltype data
    plt.hist(df1['channeltype'],bins=15, density= True)

# %%
#Call newly created function
Function_histogram()

# %%
#Create a new csv
df1.to_csv('new_youtube_dataset_1000.csv')
